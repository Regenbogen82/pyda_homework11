# %% [markdown]
# Задание 1
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.dat', sep='::', names = ['ID', 'Movie', 'Genre'], engine='python').sort_values(by='ID')
rating = pd.read_csv('ratings.dat', sep='::', names = ['UserID', 'MovieID', 'Rating', 'Timestamp'], engine='python')

# %%
rating_class = rating.groupby('MovieID', as_index=False).mean().sort_values(by='Rating', ascending=False)[['MovieID', 'Rating']]

# %%
def rating_list(data):
    if data <= 2.0:
        return 'низкий рейтинг'
    elif data <= 4.0:
        return 'средний рейтинг'
    else:
        return 'высокий рейтинг'

# %%
rating_class['Class'] = rating_class['Rating'].apply(rating_list) 
rating_class = rating_class.sort_values(by='MovieID')

# %%
movies['Class'] = rating_class['Class']
movies['Rating'] = rating_class['Rating']
movies.head()
# Out:
#    ID                               Movie                         Genre  \
# 0   1                    Toy Story (1995)   Animation|Children's|Comedy
# 1   2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2   3             Grumpier Old Men (1995)                Comedy|Romance
# 3   4            Waiting to Exhale (1995)                  Comedy|Drama
# 4   5  Father of the Bride Part II (1995)                        Comedy
#
#              Class  Year    Rating
# 0  высокий рейтинг  1995  4.146846
# 1  средний рейтинг  1995  3.201141
# 2  средний рейтинг  1995  3.016736
# 3  средний рейтинг  1995  2.729412
# 4  средний рейтинг  1995  3.006757

# %%
movies.groupby('Class').count()['Movie']
# Out:
# Class
# высокий рейтинг     370
# низкий рейтинг      219
# средний рейтинг    3117
# Name: Movie, dtype: int64

# %% [markdown]
# Задание 2
#
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
keyword = pd.read_csv('keywords.csv')
keyword.sort_values(by='shows', ascending=False).head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }

# %%
def region(data):
    for region, city in geo_data.items():
        word = data.split(' ')
        for i in word:
            if i in city:  
                return region
    return 'undefined'

# %%
keyword['region'] = keyword.keyword.apply(region)

# %%
keyword.region.value_counts()
# Out:
# undefined         99406
# Центр               384
# Северо-Запад        146
# Дальний Восток       64
# Name: region, dtype: int64

# %% [markdown]
# Задание 3 (бонусное)
#
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#
# для каждой строки пройдите по всем годам списка years
# если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга

# %%
years = list(range(1950, 2011, 1))

# %%
def production_year(data):
    for year in years:
        if str(year) in data:
            return year
    return '1900'

# %%
movies['Year'] = movies.Movie.apply(production_year)
movies.head()
# Out:
#    ID                               Movie                         Genre  \
# 0   1                    Toy Story (1995)   Animation|Children's|Comedy
# 1   2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2   3             Grumpier Old Men (1995)                Comedy|Romance
# 3   4            Waiting to Exhale (1995)                  Comedy|Drama
# 4   5  Father of the Bride Part II (1995)                        Comedy
#
#              Class  Year    Rating
# 0  высокий рейтинг  1995  4.146846
# 1  средний рейтинг  1995  3.201141
# 2  средний рейтинг  1995  3.016736
# 3  средний рейтинг  1995  2.729412
# 4  средний рейтинг  1995  3.006757

# %%
stats = movies.groupby('Year', as_index=False).mean()[['Year', 'Rating']]
stats.head()
# Out:
#    Year    Rating
# 0  1950  3.176278
# 1  1951  3.292539
# 2  1952  3.228088
# 3  1953  2.839388
# 4  1954  3.539740

# %%
import matplotlib.pyplot as plt

# %%
x = stats['Year'][0:51]
y = stats['Rating'][0:51]

# %%
plt.plot(x,y)

# %%
stats.sort_values(by='Rating', ascending=False)
# Out:
#     Year    Rating
# 4   1954  3.539740
# 7   1957  3.507449
# 11  1961  3.496937
# 29  1979  3.462969
# 10  1960  3.450660
# 13  1963  3.443263
# 14  1964  3.433348
# 23  1973  3.427995
# 28  1978  3.426002
# 41  1991  3.381016
# 30  1980  3.380726
# 12  1962  3.374731
# 24  1974  3.363528
# 42  1992  3.356912
# 35  1985  3.330516
# 26  1976  3.329617
# 31  1981  3.310723
# 51  1900  3.306170
# 33  1983  3.298276
# 1   1951  3.292539
# 45  1995  3.289356
# 38  1988  3.269373
# 19  1969  3.265184
# 40  1990  3.254647
# 32  1982  3.244257
# 44  1994  3.244161
# 27  1977  3.229205
# 2   1952  3.228088
# 39  1989  3.220226
# 21  1971  3.215247
# 22  1972  3.210723
# 48  1998  3.210601
# 43  1993  3.210174
# 49  1999  3.206228
# 18  1968  3.197964
# 16  1966  3.192852
# 36  1986  3.188953
# 46  1996  3.186252
# 5   1955  3.185478
# 0   1950  3.176278
# 15  1965  3.174099
# 20  1970  3.170843
# 9   1959  3.167986
# 17  1967  3.159015
# 50  2000  3.153887
# 47  1997  3.135586
# ...
